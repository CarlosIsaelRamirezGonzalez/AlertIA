# %%
import cv2
import imghdr
import os
from collections import defaultdict
from PIL import Image
import random
import shutil
import hashlib
# Out:
# C:\Users\taqui\AppData\Local\Temp\ipykernel_20664\135827482.py:2: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %%
data_dir = 'C:/Users/taqui/Downloads/archive (2)'

# %%
count = 1

# %%
image_exts = ['jpeg', 'jpg', 'bmp', 'png']

# %%
os.listdir(data_dir)
# Out:
# ['Armas blancas',
#  'Armas cortas',
#  'Armas largas',
#  'Ataque de perros',
#  'Choques',
#  'Enca�onamiento',
#  'Forcejeos',
#  'Golpes',
#  'Incendios',
#  'Normalidad',
#  'Patadas',
#  'Personas heridas']

# %%
os.listdir(os.path.join(data_dir, 'Incendios'))
# Out:
# ['imgV1.jpg',
#  'imgV10.jpg',
#  'imgV100.jpg',
#  'imgV1000.jpg',
#  'imgV1001.jpg',
#  'imgV1002.jpg',
#  'imgV1003.jpg',
#  'imgV1004.jpg',
#  'imgV1005.jpg',
#  'imgV1006.jpg',
#  'imgV1007.jpg',
#  'imgV1008.jpg',
#  'imgV1009.jpg',
#  'imgV101.jpg',
#  'imgV1010.jpg',
#  'imgV1011.jpg',
#  'imgV1012.jpg',
#  'imgV1013.jpg',
#  'imgV1014.jpg',
#  'imgV1015.jpg',
#  'imgV1016.jpg',
#  'imgV1017.jpg',
#  'imgV1018.jpg',
#  'imgV1019.jpg',
#  'imgV102.jpg',
#  'imgV1020.jpg',
#  'imgV1021.jpg',
#  'imgV1022.jpg',
#  'imgV1023.jpg',
#  'imgV1024.jpg',
#  'imgV1025.jpg',
#  'imgV1026.jpg',
#  'imgV1027.jpg',
#  'imgV1028.jpg',
#  'imgV1029.jpg',
#  'imgV103.jpg',
#  'imgV1030.jpg',
#  'imgV1031.jpg',
#  'imgV1032.jpg',
#  'imgV1033.jpg',
#  'imgV1034.jpg',
#  'imgV1035.jpg',
#  'imgV1036.jpg',
#  'imgV1037.jpg',
#  'imgV1038.jpg',
#  'imgV1039.jpg',
#  'imgV104.jpg',
#  'imgV1040.jpg',
#  'imgV1041.jpg',
#  'imgV1042.jpg',
#  'imgV1043.jpg',
#  'imgV1044.jpg',
#  'imgV1045.jpg',
# ...

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try:
            type = imghdr.what(image_path)
            if type not in image_exts:
                print('Image not in extension list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e:
            print('Issue with image {}'.format(image_path))
# Out:
# Image not in extension list C:/Users/taqui/Downloads/archive (2)\Normalidad\ADWAWAW (1).webp
# Image not in extension list C:/Users/taqui/Downloads/archive (2)\Normalidad\ADWAWAW (2).webp
# Image not in extension list C:/Users/taqui/Downloads/archive (2)\Normalidad\ADWAWAW (3).webp
# Image not in extension list C:/Users/taqui/Downloads/archive (2)\Normalidad\ADWAWAW (41).jpeg
# Image not in extension list C:/Users/taqui/Downloads/archive (2)\Normalidad\ADWAWAW (5).jpg
# Image not in extension list C:/Users/taqui/Downloads/archive (2)\Normalidad\depositphotos_308819170-stock-photo-cheerful-african-american-father-happy.jpg
# Image not in extension list C:/Users/taqui/Downloads/archive (2)\Normalidad\depositphotos_444424378-stock-photo-int-covid-movement-people-milan.jpg
# Image not in extension list C:/Users/taqui/Downloads/archive (2)\Normalidad\parque2-ROQnoZbqRFpOorZWIHWixJJ-1200x840abc.jpeg
# ...

# %%
import hashlib
import os

hashes = set()
images_deleted = 0

for image_class in os.listdir(data_dir):
    for filename in os.listdir(os.path.join(data_dir, image_class)):
        path = os.path.join(data_dir, image_class, filename)
        digest = hashlib.sha1(open(path,'rb').read()).digest()
        if digest not in hashes:
            hashes.add(digest)
        else:
            os.remove(path)
            images_deleted += 1

print(images_deleted)
# Out:
# 135

# %%
prefix = 'im'

# %%
for image_class in os.listdir(data_dir):
    count = 1
    for image in os.listdir(os.path.join(data_dir, image_class)):
        filename = f"{prefix}V{count}.jpg"
        os.rename(os.path.join(data_dir, image_class, image), os.path.join(data_dir, image_class, filename))
        count += 1
